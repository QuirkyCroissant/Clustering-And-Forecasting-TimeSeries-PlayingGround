# %%
train_sets = ['/kaggle/input/datasets/michalbarnas/training-data/sample_23.csv'] # do not touch
test_set = '/kaggle/input/datasets/michalbarnas/training-data/sample_24.csv' # do not touch
max_rows = -1 # -1 for the whole file

# Approximate Gaussian Process (AGP) Configuration
# AGP models use inducing points and minibatches, so they scale better than exact GPs.
# Keep these conservative if you want faster notebook runs.
GP_NUM_INDUCING_POINTS = 512  # Number of inducing points for the variational AGP
GP_EPOCHS = 6  # Training epochs for the variational objective
GP_MINIBATCH_SIZE = 512  # Minibatch size for AGP training
GP_LEARNING_RATE = 0.005  # Adam learning rate
GP_USE_LOG1P_TARGET = True  # Train in log1p-space and invert with expm1 at prediction time
GP_USE_ID_HISTORY_FEATURES = True  # Anchor each ID to its train-time level/scale statistics
GP_ID_HISTORY_EPS = 1e-6  # Numerical stability for train-scale normalization
EXPORT_COMBINED_RESULTS = True  # Export only the combined forecasts when enabled
EXPORT_BASE_DIR = None  # None => auto-detect: /kaggle/working on Kaggle, else ../data/processed

# Run toggles
RUN_ALL_DATA = False
RUN_GLOBAL_TRAIN_CLUSTER = False
RUN_GLOBAL_TRAIN_CLUSTER_COMBINED = False
RUN_CLUSTER_SPECIFIC_COMBINED = True
RUN_GLOBAL_WITH_CLUSTER_FEATURE = False

# Insert below paths to your clusterings (format required as a CSV: ID,shapelet_cluster)
clusterings = [
    '/kaggle/input/datasets/michalbarnas/feature-based-clustering/case1_clusters.csv',
    '/kaggle/input/datasets/michalbarnas/feature-based-clustering/case2_clusters.csv',
    '/kaggle/input/datasets/michalbarnas/feature-based-clustering/case3_clusters.csv',
    '/kaggle/input/datasets/michalbarnas/feature-based-clustering/case4_clusters.csv',
    '/kaggle/input/datasets/michalbarnas/feature-based-clustering/case5_clusters.csv',
    '/kaggle/input/datasets/michalbarnas/feature-based-clustering/case6_clusters.csv'
                  # 'outputs/kshape/kshape_7.csv',
                  # 'outputs/feature/case1_clusters.csv',
                  # 'outputs/feature/case2_clusters.csv',
                  # 'outputs/feature/case3_clusters.csv',
                  # 'outputs/feature/case4_clusters.csv',
                  # 'outputs/feature/case5_clusters.csv',
                  # 'outputs/feature/case6_clusters.csv',
                  # 'outputs/kmedoid/kmedoid_cluster_labels_sample_23.csv',
            ]

# %%
# %pip install gpytorch
# Out:
# Collecting gpytorch
#   Downloading gpytorch-1.15.2-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: mpmath<=1.3,>=0.19 in /usr/local/lib/python3.12/dist-packages (from gpytorch) (1.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from gpytorch) (1.6.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from gpytorch) (1.16.3)
# Collecting linear_operator>=0.6.1 (from gpytorch)
#   Downloading linear_operator-0.6.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.12/dist-packages (from linear_operator>=0.6.1->gpytorch) (2.10.0+cu128)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in /usr/local/lib/python3.12/dist-packages (from scipy>=1.6.0->gpytorch) (2.0.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->gpytorch) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->gpytorch) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (2026.2.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6.1->gpytorch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0->linear_operator>=0.6.1->gpytorch) (1.3.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0->linear_operator>=0.6.1->gpytorch) (3.0.3)
# Downloading gpytorch-1.15.2-py3-none-any.whl (291 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.2/291.2 kB 12.6 MB/s eta 0:00:00
# Downloading linear_operator-0.6.1-py3-none-any.whl (174 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.8/174.8 kB 10.5 MB/s eta 0:00:00
# Installing collected packages: linear_operator, gpytorch
# Successfully installed gpytorch-1.15.2 linear_operator-0.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import warnings

import torch
import gpytorch
from torch.utils.data import DataLoader, TensorDataset

from sklearn.cluster import MiniBatchKMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

warnings.filterwarnings('ignore')

# %%
# Helper functions
def add_calendar_features(df: pd.DataFrame) -> pd.DataFrame:
    out = df.copy()
    out["dow"] = out["date"].dt.dayofweek
    out["month"] = out["date"].dt.month
    out["day"] = out["date"].dt.day
    out["dayofyear"] = out["date"].dt.dayofyear

    out["doy_sin"] = np.sin(2 * np.pi * out["dayofyear"] / 366.0)
    out["doy_cos"] = np.cos(2 * np.pi * out["dayofyear"] / 366.0)
    out["dow_sin"] = np.sin(2 * np.pi * out["dow"] / 7.0)
    out["dow_cos"] = np.cos(2 * np.pi * out["dow"] / 7.0)
    return out


def add_lag_features(df: pd.DataFrame, group_col: str, target_col: str) -> pd.DataFrame:
    out = df.copy()
    g = out.groupby(group_col)[target_col]

    out["lag_1"] = g.shift(1)
    out["lag_7"] = g.shift(7)
    out["lag_14"] = g.shift(14)
    out["lag_28"] = g.shift(28)

    out["roll_mean_7"] = g.shift(1).rolling(7).mean().reset_index(level=0, drop=True)
    out["roll_mean_28"] = g.shift(1).rolling(28).mean().reset_index(level=0, drop=True)
    return out


def build_cluster_mapping(clustering_df):
    clustering_df = clustering_df.copy()
    clustering_df.columns = clustering_df.columns.str.strip()

    id_candidates = [c for c in clustering_df.columns if c.lower() == "id"]
    cluster_candidates = [c for c in clustering_df.columns if "cluster" in c.lower()]

    cluster_id_col = id_candidates[0] if id_candidates else clustering_df.columns[0]
    cluster_col = cluster_candidates[0] if cluster_candidates else clustering_df.columns[1]

    cluster_map = clustering_df[[cluster_id_col, cluster_col]].dropna().drop_duplicates().copy()
    cluster_map[cluster_id_col] = cluster_map[cluster_id_col].astype(str)

    cluster_values = sorted(pd.unique(cluster_map[cluster_col]))
    cluster_value_to_code = {v: i for i, v in enumerate(cluster_values)}

    id_to_cluster_value = dict(zip(cluster_map[cluster_id_col], cluster_map[cluster_col]))
    id_to_cluster_code = {
        item_id: int(cluster_value_to_code[value])
        for item_id, value in id_to_cluster_value.items()
    }

    return cluster_map, cluster_id_col, cluster_col, id_to_cluster_value, id_to_cluster_code


def train_model_with_cluster_feature(train_wide_in, id_col, id_to_cluster_code):
    def add_cluster_code_feature(df):
        out = df.copy()
        out["cluster_code"] = out[id_col].astype(str).map(id_to_cluster_code).fillna(-1).astype(float)
        return out

    train_model_fn = globals()["train_model"]
    return train_model_fn(
        train_wide_in,
        id_col,
        extra_feature_builder=add_cluster_code_feature,
        extra_feature_cols=["cluster_code"],
    )


class AGPModel(gpytorch.models.ApproximateGP):
    def __init__(self, inducing_points, input_dim):
        variational_distribution = gpytorch.variational.CholeskyVariationalDistribution(inducing_points.size(0))
        variational_strategy = gpytorch.variational.VariationalStrategy(
            self,
            inducing_points,
            variational_distribution,
            learn_inducing_locations=True,
        )
        super().__init__(variational_strategy)
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(
            gpytorch.kernels.AdditiveKernel(
                gpytorch.kernels.RBFKernel(ard_num_dims=input_dim),
                gpytorch.kernels.MaternKernel(nu=2.5, ard_num_dims=input_dim),
            )
        )

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)


class AGPBundle:
    def __init__(self, gp_model, likelihood, feature_scaler, target_scaler, device, feature_cols, use_log1p_target=False):
        self.gp_model = gp_model
        self.likelihood = likelihood
        self.scaler = feature_scaler
        self.target_scaler = target_scaler
        self.device = device
        self.feature_cols = feature_cols
        self.use_log1p_target = bool(use_log1p_target)

# %%
def preprocess_test_data(test_wide, id_col):
    test_cols = pd.Index(test_wide.columns)
    test_parsed = pd.to_datetime(test_cols, format="%Y-%m-%d", errors="coerce")
    test_date_mask = (test_cols != id_col) & test_parsed.notna()
    test_date_cols = test_cols[test_date_mask].tolist()
    future_dates = np.array(sorted(pd.to_datetime(test_date_cols)))

    test_long_actual = test_wide.melt(id_vars=id_col, value_vars=test_date_cols, var_name="date", value_name="y_true")
    test_long_actual["date"] = pd.to_datetime(test_long_actual["date"])
    return future_dates, test_long_actual

# %%
def train_model(train_wide, id_col, extra_feature_builder=None, extra_feature_cols=None):
    train_cols = pd.Index(train_wide.columns)
    train_parsed = pd.to_datetime(train_cols, format="%Y-%m-%d", errors="coerce")
    train_date_mask = (train_cols != id_col) & train_parsed.notna()
    train_date_cols = train_cols[train_date_mask].tolist()

    train_long = train_wide.melt(id_vars=id_col, value_vars=train_date_cols, var_name="date", value_name="y")
    train_long["date"] = pd.to_datetime(train_long["date"])
    train_long = train_long.sort_values([id_col, "date"]).reset_index(drop=True)

    print("Adding features")
    train_feat = add_calendar_features(train_long)
    train_feat = add_lag_features(train_feat, group_col=id_col, target_col="y")

    if extra_feature_builder is not None:
        train_feat = extra_feature_builder(train_feat)

    id_feature_maps = None
    use_id_history_features = bool(globals().get("GP_USE_ID_HISTORY_FEATURES", True))
    if use_id_history_features:
        eps = float(globals().get("GP_ID_HISTORY_EPS", 1e-6))

        id_stats = (
            train_long
            .groupby(id_col)["y"]
            .agg(id_train_mean="mean", id_train_std="std")
            .reset_index()
        )
        id_stats["id_train_std"] = id_stats["id_train_std"].fillna(0.0)

        train_feat = train_feat.merge(id_stats, on=id_col, how="left")
        train_feat["id_train_std_safe"] = train_feat["id_train_std"].fillna(0.0) + eps
        train_feat["lag_1_minus_id_train_mean"] = train_feat["lag_1"] - train_feat["id_train_mean"]
        train_feat["lag_1_id_train_z"] = train_feat["lag_1_minus_id_train_mean"] / train_feat["id_train_std_safe"]

        id_feature_maps = {
            "mean_by_id": dict(zip(id_stats[id_col].astype(str), id_stats["id_train_mean"].astype(float))),
            "std_by_id": dict(zip(id_stats[id_col].astype(str), id_stats["id_train_std"].astype(float))),
            "global_mean": float(train_long["y"].mean()),
            "global_std": float(train_long["y"].std()) if pd.notna(train_long["y"].std()) else 0.0,
            "eps": eps,
        }

    feature_cols = [
        "dow", "month", "day", "dayofyear",
        "doy_sin", "doy_cos", "dow_sin", "dow_cos",
        "lag_1", "lag_7", "lag_14", "lag_28",
        "roll_mean_7", "roll_mean_28",
    ]

    if use_id_history_features:
        feature_cols.extend([
            "id_train_mean",
            "id_train_std",
            "lag_1_minus_id_train_mean",
            "lag_1_id_train_z",
        ])

    if extra_feature_cols:
        feature_cols.extend(extra_feature_cols)

    train_model_df = train_feat.dropna(subset=feature_cols + ["y"]).copy()
    if len(train_model_df) == 0:
        raise ValueError("No rows available after feature engineering.")

    # Use all available training data without downsampling
    print(f"Training with {len(train_model_df)} samples")

    X_train = train_model_df[feature_cols].to_numpy(dtype=float)
    y_train_raw = train_model_df["y"].to_numpy(dtype=float)

    use_log1p_target = bool(globals().get("GP_USE_LOG1P_TARGET", False))
    if use_log1p_target:
        y_train_raw = np.clip(y_train_raw, a_min=0.0, a_max=None)
        y_train_for_model = np.log1p(y_train_raw)
    else:
        y_train_for_model = y_train_raw

    print("Standardizing features and target")
    feature_scaler = StandardScaler()
    X_train_scaled = feature_scaler.fit_transform(X_train)
    target_scaler = StandardScaler()
    y_train_scaled = target_scaler.fit_transform(y_train_for_model.reshape(-1, 1)).ravel()

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    x_tensor = torch.from_numpy(X_train_scaled).float()
    y_tensor = torch.from_numpy(y_train_scaled).float()

    num_inducing = min(int(globals().get("GP_NUM_INDUCING_POINTS", 256)), len(X_train_scaled))
    rng = np.random.default_rng(42)
    print(f"Initializing {num_inducing} inducing points using k-means centers")

    try:
        if num_inducing < len(X_train_scaled):
            kmeans_batch_size = min(max(1024, num_inducing * 4), len(X_train_scaled))
            kmeans = MiniBatchKMeans(
                n_clusters=num_inducing,
                random_state=42,
                n_init=10,
                batch_size=kmeans_batch_size,
            )
            kmeans.fit(X_train_scaled)
            inducing_np = kmeans.cluster_centers_.astype(np.float32, copy=False)
        else:
            inducing_np = X_train_scaled.astype(np.float32, copy=False)
    except Exception as exc:
        # Keep training robust if k-means fails for any edge case.
        print(f"K-means inducing init failed ({exc}); falling back to random subset.")
        inducing_idx = rng.choice(len(X_train_scaled), size=num_inducing, replace=False)
        inducing_np = X_train_scaled[inducing_idx].astype(np.float32, copy=False)

    inducing_points = torch.from_numpy(inducing_np).float().to(device)

    train_dataset = TensorDataset(x_tensor, y_tensor)
    batch_size = min(int(globals().get("GP_MINIBATCH_SIZE", 2048)), len(train_dataset))
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=False)

    print("Fitting AGP model")
    gp_model = AGPModel(inducing_points=inducing_points, input_dim=X_train_scaled.shape[1]).to(device)
    likelihood = gpytorch.likelihoods.GaussianLikelihood().to(device)
    gp_model.train()
    likelihood.train()

    optimizer = torch.optim.Adam(
        list(gp_model.parameters()) + list(likelihood.parameters()),
        lr=float(globals().get("GP_LEARNING_RATE", 0.01)),
    )
    mll = gpytorch.mlls.VariationalELBO(likelihood, gp_model, num_data=len(train_dataset))

    num_epochs = int(globals().get("GP_EPOCHS", 4))
    for epoch in range(num_epochs):
        epoch_loss = 0.0
        for batch_x, batch_y in train_loader:
            batch_x = batch_x.to(device)
            batch_y = batch_y.to(device)

            optimizer.zero_grad()
            output = gp_model(batch_x)
            loss = -mll(output, batch_y)
            loss.backward()
            optimizer.step()
            epoch_loss += float(loss.item()) * len(batch_x)

        avg_loss = epoch_loss / max(len(train_dataset), 1)
        print(f"Epoch {epoch + 1}/{num_epochs} - loss: {avg_loss:.4f}")

    gp_model.eval()
    likelihood.eval()

    model = AGPBundle(
        gp_model=gp_model,
        likelihood=likelihood,
        feature_scaler=feature_scaler,
        target_scaler=target_scaler,
        device=device,
        feature_cols=feature_cols,
        use_log1p_target=use_log1p_target,
    )
    model.id_feature_maps = id_feature_maps

    return model, feature_cols

# %%
def predict(model, future_dates, id_values, train_wide, id_col, feature_cols, extra_feature_builder=None):
    n_ids = len(id_values)
    n_steps = len(future_dates)
    pred_matrix = np.empty((n_ids, n_steps), dtype=float)
    uncertainty_matrix = np.empty((n_ids, n_steps), dtype=float)  # AGP provides uncertainty estimates

    train_date_cols = [
        c for c in train_wide.columns
        if c != id_col and pd.notna(pd.to_datetime(c, format="%Y-%m-%d", errors="coerce"))
    ]

    if len(train_date_cols) == 0:
        raise ValueError("No valid date columns found in train data.")

    train_wide_indexed = train_wide.set_index(id_col)

    history_by_id = {}
    for item_id in id_values:
        if item_id in train_wide_indexed.index:
            hist_series = train_wide_indexed.loc[item_id, train_date_cols]
            history_by_id[item_id] = np.asarray(hist_series, dtype=float).tolist()
        else:
            history_by_id[item_id] = []

    print("Predicting with AGP...")
    scaler = model.scaler
    target_scaler = model.target_scaler
    gp_model = model.gp_model
    likelihood = model.likelihood
    device = model.device
    use_log1p_target = bool(getattr(model, "use_log1p_target", False))
    id_feature_maps = getattr(model, "id_feature_maps", None)

    gp_model.eval()
    likelihood.eval()

    for step_idx, dt in enumerate(future_dates):
        dow = dt.dayofweek
        month = dt.month
        day = dt.day
        dayofyear = dt.dayofyear

        doy_sin = np.sin(2 * np.pi * dayofyear / 366.0)
        doy_cos = np.cos(2 * np.pi * dayofyear / 366.0)
        dow_sin = np.sin(2 * np.pi * dow / 7.0)
        dow_cos = np.cos(2 * np.pi * dow / 7.0)

        X_batch = np.empty((n_ids, len(feature_cols)), dtype=float)

        for i, item_id in enumerate(id_values):
            hist = history_by_id[item_id]

            lag_1 = hist[-1] if len(hist) >= 1 else np.nan
            lag_7 = hist[-7] if len(hist) >= 7 else lag_1
            lag_14 = hist[-14] if len(hist) >= 14 else lag_1
            lag_28 = hist[-28] if len(hist) >= 28 else lag_1

            roll_mean_7 = np.mean(hist[-7:]) if len(hist) >= 7 else lag_1
            roll_mean_28 = np.mean(hist[-28:]) if len(hist) >= 28 else lag_1

            row_features = [
                dow, month, day, dayofyear,
                doy_sin, doy_cos, dow_sin, dow_cos,
                lag_1, lag_7, lag_14, lag_28,
                roll_mean_7, roll_mean_28,
            ]

            if id_feature_maps is not None:
                key = str(item_id)
                mean_by_id = id_feature_maps.get("mean_by_id", {})
                std_by_id = id_feature_maps.get("std_by_id", {})
                global_mean = float(id_feature_maps.get("global_mean", 0.0))
                global_std = float(id_feature_maps.get("global_std", 0.0))
                eps = float(id_feature_maps.get("eps", 1e-6))

                id_train_mean = float(mean_by_id.get(key, global_mean))
                id_train_std = max(float(std_by_id.get(key, global_std)), 0.0)

                lag_1_safe = lag_1 if np.isfinite(lag_1) else id_train_mean
                lag_1_minus_id_train_mean = lag_1_safe - id_train_mean
                lag_1_id_train_z = lag_1_minus_id_train_mean / (id_train_std + eps)

                row_features.extend([
                    id_train_mean,
                    id_train_std,
                    lag_1_minus_id_train_mean,
                    lag_1_id_train_z,
                ])

            if extra_feature_builder is not None:
                extra_features = extra_feature_builder(item_id=item_id, dt=dt, hist=hist)
                row_features.extend(extra_features)

            X_batch[i, :] = row_features

        # Scale features before prediction
        X_batch_scaled = scaler.transform(X_batch)
        x_tensor = torch.from_numpy(X_batch_scaled).float().to(device)

        with torch.no_grad(), gpytorch.settings.fast_pred_var():
            pred_dist = likelihood(gp_model(x_tensor))
            mean_scaled = pred_dist.mean.detach().cpu().numpy()
            std_scaled = pred_dist.variance.clamp_min(1e-12).sqrt().detach().cpu().numpy()

        y_pred_model_space = mean_scaled * target_scaler.scale_[0] + target_scaler.mean_[0]
        y_std_model_space = std_scaled * target_scaler.scale_[0]

        if use_log1p_target:
            # Inverse of log1p target transform with delta-method std approximation.
            y_pred_batch = np.expm1(y_pred_model_space)
            y_pred_batch = np.clip(y_pred_batch, a_min=0.0, a_max=None)
            y_std_batch = np.exp(y_pred_model_space) * y_std_model_space
        else:
            y_pred_batch = y_pred_model_space
            y_std_batch = y_std_model_space

        pred_matrix[:, step_idx] = y_pred_batch
        uncertainty_matrix[:, step_idx] = y_std_batch

        for i, item_id in enumerate(id_values):
            history_by_id[item_id].append(float(y_pred_batch[i]))

    pred_long = pd.DataFrame(
        {
            id_col: np.repeat(id_values, n_steps),
            "date": np.tile(future_dates, n_ids),
            "y_pred": pred_matrix.reshape(-1),
            "y_std": uncertainty_matrix.reshape(-1),  # Include uncertainty estimates
        }
    )

    return pred_long


def predict_with_cluster_feature(model, future_dates, id_values, train_wide_in, id_col, feature_cols, id_to_cluster_code):
    def add_cluster_feature(item_id, dt, hist):
        _ = (dt, hist)
        return [float(id_to_cluster_code.get(item_id, -1))]

    return predict(
        model,
        future_dates,
        id_values,
        train_wide_in,
        id_col,
        feature_cols,
        extra_feature_builder=add_cluster_feature,
    )

# %%
def evaluate(pred_long, train_long, test_long_actual, id_col):
    train_rows = len(train_long)
    if train_rows == 0:
        print("No training rows provided.")

    eval_df = pred_long.merge(test_long_actual, on=[id_col, "date"], how="left")

    valid_mask = eval_df["y_true"].notna()

    metrics = {
        "mae": np.nan,
        "rmse": np.nan,
        "nrmse_mean": np.nan,
        "cvrmse_pct": np.nan,
        "nrmse_range": np.nan,
        "n_eval_points": int(valid_mask.sum()),
    }

    if valid_mask.any():
        y_true = eval_df.loc[valid_mask, "y_true"]
        y_pred = eval_df.loc[valid_mask, "y_pred"]

        mae = mean_absolute_error(y_true, y_pred)
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))

        mean_true = float(y_true.mean())
        y_true_range = float(y_true.max() - y_true.min())

        nrmse_mean = (rmse / mean_true) if abs(mean_true) > 1e-12 else np.nan
        cvrmse_pct = 100.0 * nrmse_mean if np.isfinite(nrmse_mean) else np.nan
        nrmse_range = (rmse / y_true_range) if y_true_range > 1e-12 else np.nan

        metrics.update(
            {
                "mae": float(mae),
                "rmse": float(rmse),
                "nrmse_mean": float(nrmse_mean) if np.isfinite(nrmse_mean) else np.nan,
                "cvrmse_pct": float(cvrmse_pct) if np.isfinite(cvrmse_pct) else np.nan,
                "nrmse_range": float(nrmse_range) if np.isfinite(nrmse_range) else np.nan,
            }
        )

    pred_wide = pred_long.copy()
    pred_wide["date"] = pred_wide["date"].dt.strftime("%Y-%m-%d")
    
    # Keep y_std if available (from AGP predictions)
    if "y_std" in pred_wide.columns:
        pred_wide = pred_wide.pivot_table(index=id_col, columns="date", values="y_pred").reset_index()
    else:
        pred_wide = pred_wide.pivot(index=id_col, columns="date", values="y_pred").reset_index()

    metrics["n_pred_rows"] = int(len(pred_long))

    return metrics, pred_wide, eval_df


def print_evaluation_summary(results):
    if len(results) == 0:
        print("No evaluation results to summarize.")
        return

    summary_df = pd.DataFrame(results)

    cols = [
        "clustering_used",
        "label",
        "n_eval_points",
        "mae",
        "rmse",
        "cvrmse_pct",
        "nrmse_range",
    ]
    cols = [c for c in cols if c in summary_df.columns]

    print("Evaluation Summary")
    print(summary_df[cols].to_string(index=False))

    numeric_cols = ["mae", "rmse", "cvrmse_pct", "nrmse_range"]
    available_numeric = [c for c in numeric_cols if c in summary_df.columns]

    if len(available_numeric) > 0:
        print("\nAverages")
        print(summary_df[available_numeric].mean(numeric_only=True).to_string())

# %%
def run(train_data, test_data, id_col, label="run"):
    train_data = train_data.copy()
    test_data = test_data.copy()

    # Normalize incoming column names and requested id column to avoid whitespace mismatches.
    train_data.columns = train_data.columns.str.strip()
    test_data.columns = test_data.columns.str.strip()
    id_col = id_col.strip()

    if id_col not in train_data.columns:
        raise ValueError(f"ID column '{id_col}' not found in train data. Available: {list(train_data.columns[:5])}...")
    if id_col not in test_data.columns:
        raise ValueError(f"ID column '{id_col}' not found in test data. Available: {list(test_data.columns[:5])}...")

    model, feature_cols = train_model(train_data, id_col)

    id_values = np.array(sorted(pd.unique(test_data[id_col].dropna())))
    if len(id_values) == 0:
        raise ValueError("No IDs found in test data.")

    future_dates, test_long_actual = preprocess_test_data(test_data, id_col)

    pred_long = predict(model, future_dates, id_values, train_data, id_col, feature_cols)

    metrics, pred_wide, eval_df = evaluate(
        pred_long,
        train_data.melt(id_vars=id_col, var_name="date", value_name="y"),
        test_long_actual,
        id_col,
    )
    metrics["label"] = label

    return metrics, pred_wide, eval_df

# %%
from pathlib import Path

# Data loading
train_path = train_sets[0] if isinstance(train_sets, (list, tuple)) else train_sets
test_path = test_set

if max_rows != -1:
    train_wide = pd.read_csv(train_path, nrows=max_rows)
    test_wide = pd.read_csv(test_path, nrows=max_rows)
else:
    train_wide = pd.read_csv(train_path)
    test_wide = pd.read_csv(test_path)

results = []

run_all_data = bool(globals().get("RUN_ALL_DATA", True))
run_global_train_cluster = bool(globals().get("RUN_GLOBAL_TRAIN_CLUSTER", True))
run_global_train_cluster_combined = bool(globals().get("RUN_GLOBAL_TRAIN_CLUSTER_COMBINED", True))
run_cluster_specific_combined = bool(globals().get("RUN_CLUSTER_SPECIFIC_COMBINED", True))
run_global_with_cluster_feature = bool(globals().get("RUN_GLOBAL_WITH_CLUSTER_FEATURE", True))
export_combined_results = bool(globals().get("EXPORT_COMBINED_RESULTS", False))


def resolve_export_base_dir():
    override_dir = globals().get("EXPORT_BASE_DIR", None)

    if isinstance(override_dir, str) and override_dir.strip():
        base_dir = Path(override_dir).expanduser()
    elif Path("/kaggle/working").exists():
        # Kaggle notebooks can only write safely to /kaggle/working.
        base_dir = Path("/kaggle/working")
    else:
        base_dir = Path("../data/processed")

    base_dir.mkdir(parents=True, exist_ok=True)
    return base_dir


export_base_dir = resolve_export_base_dir()
print(f"Combined forecast exports will be written to: {export_base_dir.resolve()}")

if run_all_data:
    print("Running without clusters")
    base_metrics, _, _ = run(
        train_wide,
        test_wide,
        id_col="ID",
        label="all_data",
    )
    base_metrics["clustering_used"] = "none"
    results.append(base_metrics)
else:
    print("Skipping all-data forecast (RUN_ALL_DATA=False)")

train_norm = train_wide.copy()
train_norm.columns = train_norm.columns.str.strip()
train_norm["ID"] = train_norm["ID"].astype(str)

test_norm = test_wide.copy()
test_norm.columns = test_norm.columns.str.strip()
test_norm["ID"] = test_norm["ID"].astype(str)


def build_train_long(train_wide_in, id_col):
    train_cols = pd.Index(train_wide_in.columns)
    train_date_mask = (train_cols != id_col) & pd.to_datetime(
        train_cols, format="%Y-%m-%d", errors="coerce"
    ).notna()
    train_date_cols = train_cols[train_date_mask].tolist()
    train_long = train_wide_in.melt(
        id_vars=id_col, value_vars=train_date_cols, var_name="date", value_name="y"
    )
    train_long["date"] = pd.to_datetime(train_long["date"])
    return train_long


def evaluate_and_record(pred_long, train_wide_in, test_wide_in, id_col, label, clustering_used):
    _, test_long_actual = preprocess_test_data(test_wide_in, id_col)
    train_long = build_train_long(train_wide_in, id_col)

    metrics, _, _ = evaluate(
        pred_long,
        train_long,
        test_long_actual,
        id_col,
    )
    metrics["label"] = label
    metrics["clustering_used"] = clustering_used
    results.append(metrics)


def export_combined_pred_wide(combined_pred_wide, clustering_used, export_label):
    if not export_combined_results:
        return

    safe_label = str(export_label).replace(" ", "_")
    safe_clustering = str(clustering_used).replace(" ", "_")
    export_path = export_base_dir / f"sklearn_forecast_2024_{safe_label}_{safe_clustering}.csv"
    combined_pred_wide.to_csv(export_path, index=False)
    print(f"Exported combined results to {export_path.resolve()}")


def evaluate_cluster_specific_combined(train_norm_in, test_norm_in, cluster_map, cluster_id_col, cluster_col, clustering_used):
    cluster_pred_wide_parts = []

    for _, group in cluster_map.groupby(cluster_col):
        cluster_value = group[cluster_col].iloc[0]
        cluster_ids = set(group[cluster_id_col].tolist())

        train_cluster = train_norm_in[train_norm_in["ID"].isin(cluster_ids)].copy()
        test_cluster = test_norm_in[test_norm_in["ID"].isin(cluster_ids)].copy()

        if len(train_cluster) == 0 or len(test_cluster) == 0:
            continue

        cluster_metrics, cluster_pred_wide, _ = run(
            train_cluster,
            test_cluster,
            id_col="ID",
            label=f"cluster_specific_train_cluster_{cluster_value}",
        )
        cluster_metrics["clustering_used"] = clustering_used
        results.append(cluster_metrics)
        cluster_pred_wide_parts.append(cluster_pred_wide)

    if len(cluster_pred_wide_parts) == 0:
        return

    combined_pred_wide = pd.concat(cluster_pred_wide_parts, ignore_index=True)
    combined_pred_wide = combined_pred_wide.drop_duplicates(subset=["ID"], keep="last")
    combined_pred_long = combined_pred_wide.melt(
        id_vars="ID", var_name="date", value_name="y_pred"
    )
    combined_pred_long["date"] = pd.to_datetime(combined_pred_long["date"])

    evaluate_and_record(
        combined_pred_long,
        train_norm_in,
        test_norm_in,
        "ID",
        "cluster_specific_train_combined",
        clustering_used,
    )
    export_combined_pred_wide(combined_pred_wide, clustering_used, "cluster_specific_combined")


def evaluate_global_with_cluster_feature(train_norm_in, test_norm_in, id_to_cluster_code, label, clustering_used):
    model_cf, feature_cols_cf = train_model_with_cluster_feature(train_norm_in, "ID", id_to_cluster_code)

    id_values = np.array(sorted(pd.unique(test_norm_in["ID"].dropna())))
    future_dates, _ = preprocess_test_data(test_norm_in, "ID")

    pred_long_cf = predict_with_cluster_feature(
        model_cf,
        future_dates,
        id_values,
        train_norm_in,
        "ID",
        feature_cols_cf,
        id_to_cluster_code,
    )

    evaluate_and_record(
        pred_long_cf,
        train_norm_in,
        test_norm_in,
        "ID",
        label,
        clustering_used,
    )


for clustering_path in clusterings:
    print("## CLUSTERING FILE:", clustering_path)
    clustering_used = clustering_path.split('/')[-1].replace('.csv', '')
    clustering_df = pd.read_csv(clustering_path)

    (
        cluster_map,
        cluster_id_col,
        cluster_col,
        id_to_cluster_value,
        id_to_cluster_code,
    ) = build_cluster_mapping(clustering_df)

    cluster_pred_wide_parts = []

    if run_global_train_cluster:
        for _, group in cluster_map.groupby(cluster_col):
            cluster_value = group[cluster_col].iloc[0]
            cluster_ids = set(group[cluster_id_col].tolist())
            test_cluster = test_norm[test_norm["ID"].isin(cluster_ids)].copy()
            if len(test_cluster) == 0:
                continue

            cluster_metrics, cluster_pred_wide, _ = run(
                train_norm,
                test_cluster,
                id_col="ID",
                label=f"global_train_cluster_{cluster_value}",
            )
            cluster_metrics["clustering_used"] = clustering_used
            results.append(cluster_metrics)
            cluster_pred_wide_parts.append(cluster_pred_wide)
    else:
        print(f"Skipping global per-cluster forecasts for {clustering_used} (RUN_GLOBAL_TRAIN_CLUSTER=False)")

    if run_global_train_cluster_combined and len(cluster_pred_wide_parts) > 0:
        combined_pred_wide = pd.concat(cluster_pred_wide_parts, ignore_index=True)
        combined_pred_wide = combined_pred_wide.drop_duplicates(subset=["ID"], keep="last")
        combined_pred_long = combined_pred_wide.melt(
            id_vars="ID", var_name="date", value_name="y_pred"
        )
        combined_pred_long["date"] = pd.to_datetime(combined_pred_long["date"])

        evaluate_and_record(
            combined_pred_long,
            train_norm,
            test_norm,
            "ID",
            "global_train_cluster_combined",
            clustering_used,
        )
        export_combined_pred_wide(combined_pred_wide, clustering_used, "global_train_combined")
    elif run_global_train_cluster_combined:
        print(f"Skipping combined global per-cluster forecast for {clustering_used} (no cluster predictions)")
    else:
        print(f"Skipping combined global per-cluster forecasts for {clustering_used} (RUN_GLOBAL_TRAIN_CLUSTER_COMBINED=False)")

    if run_cluster_specific_combined:
        evaluate_cluster_specific_combined(
            train_norm,
            test_norm,
            cluster_map,
            cluster_id_col,
            cluster_col,
            clustering_used=clustering_used,
        )
    else:
        print(f"Skipping cluster-specific combined forecasts for {clustering_used} (RUN_CLUSTER_SPECIFIC_COMBINED=False)")

    if run_global_with_cluster_feature:
        evaluate_global_with_cluster_feature(
            train_norm,
            test_norm,
            id_to_cluster_code,
            label="global_with_cluster_feature",
            clustering_used=clustering_used,
        )
    else:
        print(f"Skipping global-with-cluster-feature forecasts for {clustering_used} (RUN_GLOBAL_WITH_CLUSTER_FEATURE=False)")

print_evaluation_summary(results)
# Out:
# Combined forecast exports will be written to: /kaggle/working
# Skipping all-data forecast (RUN_ALL_DATA=False)
# ## CLUSTERING FILE: /kaggle/input/datasets/michalbarnas/feature-based-clustering/case1_clusters.csv
# Skipping global per-cluster forecasts for case1_clusters (RUN_GLOBAL_TRAIN_CLUSTER=False)
# Skipping combined global per-cluster forecasts for case1_clusters (RUN_GLOBAL_TRAIN_CLUSTER_COMBINED=False)
# Adding features
# Training with 51898 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 1.0854
# Epoch 2/6 - loss: 0.5882
# Epoch 3/6 - loss: 0.2842
# Epoch 4/6 - loss: -0.0095
# Epoch 5/6 - loss: -0.3018
# Epoch 6/6 - loss: -0.5910
# Predicting with AGP...
# Adding features
# Training with 4260017 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 0.5899
# Epoch 2/6 - loss: 0.5126
# Epoch 3/6 - loss: 0.5092
# Epoch 4/6 - loss: 0.5076
# Epoch 5/6 - loss: 0.5068
# Epoch 6/6 - loss: 0.5063
# Predicting with AGP...
# Adding features
# Training with 704667 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 0.8505
# Epoch 2/6 - loss: 0.4843
# Epoch 3/6 - loss: 0.4602
# Epoch 4/6 - loss: 0.4517
# Epoch 5/6 - loss: 0.4474
# Epoch 6/6 - loss: 0.4446
# Predicting with AGP...
# Adding features
# Training with 645692 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 0.8084
# Epoch 2/6 - loss: 0.3846
# Epoch 3/6 - loss: 0.3563
# Epoch 4/6 - loss: 0.3458
# Epoch 5/6 - loss: 0.3401
# Epoch 6/6 - loss: 0.3361
# Predicting with AGP...
# Adding features
# Training with 94360 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 1.6315
# Epoch 2/6 - loss: 1.1570
# Epoch 3/6 - loss: 0.9935
# Epoch 4/6 - loss: 0.8789
# Epoch 5/6 - loss: 0.8121
# Epoch 6/6 - loss: 0.7747
# Predicting with AGP...
# Adding features
# Training with 28308 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.0423
# Epoch 2/6 - loss: 1.4892
# Epoch 3/6 - loss: 1.2544
# Epoch 4/6 - loss: 1.1266
# Epoch 5/6 - loss: 1.0287
# Epoch 6/6 - loss: 0.9386
# Predicting with AGP...
# Adding features
# Training with 28982 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.0052
# Epoch 2/6 - loss: 1.5823
# Epoch 3/6 - loss: 1.4394
# Epoch 4/6 - loss: 1.3685
# Epoch 5/6 - loss: 1.3226
# Epoch 6/6 - loss: 1.2890
# Predicting with AGP...
# Adding features
# Training with 15502 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.2479
# Epoch 2/6 - loss: 1.9050
# Epoch 3/6 - loss: 1.6748
# Epoch 4/6 - loss: 1.5232
# Epoch 5/6 - loss: 1.4220
# Epoch 6/6 - loss: 1.3511
# Predicting with AGP...
# Adding features
# Training with 66726 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 1.9212
# Epoch 2/6 - loss: 1.3663
# Epoch 3/6 - loss: 1.1922
# Epoch 4/6 - loss: 1.0784
# Epoch 5/6 - loss: 0.9853
# Epoch 6/6 - loss: 0.9199
# Predicting with AGP...
# Adding features
# Training with 17187 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.2609
# Epoch 2/6 - loss: 1.9049
# Epoch 3/6 - loss: 1.6361
# Epoch 4/6 - loss: 1.4638
# Epoch 5/6 - loss: 1.3513
# Epoch 6/6 - loss: 1.2715
# Predicting with AGP...
# Exported combined results to /kaggle/working/sklearn_forecast_2024_cluster_specific_combined_case1_clusters.csv
# Skipping global-with-cluster-feature forecasts for case1_clusters (RUN_GLOBAL_WITH_CLUSTER_FEATURE=False)
# ## CLUSTERING FILE: /kaggle/input/datasets/michalbarnas/feature-based-clustering/case2_clusters.csv
# Skipping global per-cluster forecasts for case2_clusters (RUN_GLOBAL_TRAIN_CLUSTER=False)
# Skipping combined global per-cluster forecasts for case2_clusters (RUN_GLOBAL_TRAIN_CLUSTER_COMBINED=False)
# Adding features
# Training with 51898 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 1.0839
# Epoch 2/6 - loss: 0.5877
# Epoch 3/6 - loss: 0.2836
# Epoch 4/6 - loss: -0.0104
# Epoch 5/6 - loss: -0.3029
# Epoch 6/6 - loss: -0.5915
# Predicting with AGP...
# Adding features
# Training with 657150 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 0.8030
# Epoch 2/6 - loss: 0.3816
# Epoch 3/6 - loss: 0.3544
# Epoch 4/6 - loss: 0.3444
# Epoch 5/6 - loss: 0.3385
# Epoch 6/6 - loss: 0.3344
# Predicting with AGP...
# Adding features
# Training with 1084803 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 0.7048
# Epoch 2/6 - loss: 0.4278
# Epoch 3/6 - loss: 0.4131
# Epoch 4/6 - loss: 0.4077
# Epoch 5/6 - loss: 0.4049
# Epoch 6/6 - loss: 0.4032
# Predicting with AGP...
# Adding features
# Training with 3868423 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 0.6216
# Epoch 2/6 - loss: 0.5401
# Epoch 3/6 - loss: 0.5369
# Epoch 4/6 - loss: 0.5356
# Epoch 5/6 - loss: 0.5348
# Epoch 6/6 - loss: 0.5343
# Predicting with AGP...
# Adding features
# Training with 149291 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 1.4419
# Epoch 2/6 - loss: 0.8792
# Epoch 3/6 - loss: 0.6272
# Epoch 4/6 - loss: 0.5368
# Epoch 5/6 - loss: 0.4992
# Epoch 6/6 - loss: 0.4767
# Predicting with AGP...
# Adding features
# Training with 1011 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.4502
# Epoch 2/6 - loss: 2.4212
# Epoch 3/6 - loss: 2.3934
# Epoch 4/6 - loss: 2.3650
# Epoch 5/6 - loss: 2.3381
# Epoch 6/6 - loss: 2.3118
# Predicting with AGP...
# Adding features
# Training with 1348 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.4475
# Epoch 2/6 - loss: 2.4111
# Epoch 3/6 - loss: 2.3763
# Epoch 4/6 - loss: 2.3423
# Epoch 5/6 - loss: 2.3091
# Epoch 6/6 - loss: 2.2771
# Predicting with AGP...
# Adding features
# Training with 87957 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 1.7266
# Epoch 2/6 - loss: 1.1743
# Epoch 3/6 - loss: 0.9764
# Epoch 4/6 - loss: 0.8267
# Epoch 5/6 - loss: 0.7362
# Epoch 6/6 - loss: 0.6882
# Predicting with AGP...
# Adding features
# Training with 4718 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.4019
# Epoch 2/6 - loss: 2.2803
# Epoch 3/6 - loss: 2.1697
# Epoch 4/6 - loss: 2.0685
# Epoch 5/6 - loss: 1.9763
# Epoch 6/6 - loss: 1.8915
# Predicting with AGP...
# Adding features
# Training with 6740 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.3782
# Epoch 2/6 - loss: 2.2137
# Epoch 3/6 - loss: 2.0668
# Epoch 4/6 - loss: 1.9341
# Epoch 5/6 - loss: 1.8164
# Epoch 6/6 - loss: 1.7120
# Predicting with AGP...
# Exported combined results to /kaggle/working/sklearn_forecast_2024_cluster_specific_combined_case2_clusters.csv
# Skipping global-with-cluster-feature forecasts for case2_clusters (RUN_GLOBAL_WITH_CLUSTER_FEATURE=False)
# ## CLUSTERING FILE: /kaggle/input/datasets/michalbarnas/feature-based-clustering/case3_clusters.csv
# Skipping global per-cluster forecasts for case3_clusters (RUN_GLOBAL_TRAIN_CLUSTER=False)
# Skipping combined global per-cluster forecasts for case3_clusters (RUN_GLOBAL_TRAIN_CLUSTER_COMBINED=False)
# Adding features
# Training with 51898 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 1.0837
# Epoch 2/6 - loss: 0.5876
# Epoch 3/6 - loss: 0.2833
# Epoch 4/6 - loss: -0.0108
# Epoch 5/6 - loss: -0.3036
# Epoch 6/6 - loss: -0.5928
# Predicting with AGP...
# Adding features
# Training with 1073682 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 0.7626
# Epoch 2/6 - loss: 0.5055
# Epoch 3/6 - loss: 0.4917
# Epoch 4/6 - loss: 0.4864
# Epoch 5/6 - loss: 0.4836
# Epoch 6/6 - loss: 0.4819
# Predicting with AGP...
# Adding features
# Training with 1146137 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 0.6864
# Epoch 2/6 - loss: 0.4111
# Epoch 3/6 - loss: 0.3957
# Epoch 4/6 - loss: 0.3902
# Epoch 5/6 - loss: 0.3878
# Epoch 6/6 - loss: 0.3865
# Predicting with AGP...
# Adding features
# Training with 1341260 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 0.8187
# Epoch 2/6 - loss: 0.6324
# Epoch 3/6 - loss: 0.6183
# Epoch 4/6 - loss: 0.6132
# Epoch 5/6 - loss: 0.6103
# Epoch 6/6 - loss: 0.6087
# Predicting with AGP...
# Adding features
# Training with 2049297 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 0.5279
# Epoch 2/6 - loss: 0.3590
# Epoch 3/6 - loss: 0.3514
# Epoch 4/6 - loss: 0.3478
# Epoch 5/6 - loss: 0.3457
# Epoch 6/6 - loss: 0.3440
# Predicting with AGP...
# Adding features
# Training with 94360 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 1.6313
# Epoch 2/6 - loss: 1.1566
# Epoch 3/6 - loss: 0.9943
# Epoch 4/6 - loss: 0.8791
# Epoch 5/6 - loss: 0.8125
# Epoch 6/6 - loss: 0.7751
# Predicting with AGP...
# Adding features
# Training with 28308 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.0416
# Epoch 2/6 - loss: 1.4892
# Epoch 3/6 - loss: 1.2553
# Epoch 4/6 - loss: 1.1274
# Epoch 5/6 - loss: 1.0290
# Epoch 6/6 - loss: 0.9388
# Predicting with AGP...
# Adding features
# Training with 28982 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.0045
# Epoch 2/6 - loss: 1.5834
# Epoch 3/6 - loss: 1.4414
# Epoch 4/6 - loss: 1.3701
# Epoch 5/6 - loss: 1.3246
# Epoch 6/6 - loss: 1.2912
# Predicting with AGP...
# Adding features
# Training with 15502 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.2511
# Epoch 2/6 - loss: 1.9101
# Epoch 3/6 - loss: 1.6786
# Epoch 4/6 - loss: 1.5265
# Epoch 5/6 - loss: 1.4248
# Epoch 6/6 - loss: 1.3531
# Predicting with AGP...
# Adding features
# Training with 66726 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 1.9203
# Epoch 2/6 - loss: 1.3664
# Epoch 3/6 - loss: 1.1924
# Epoch 4/6 - loss: 1.0784
# Epoch 5/6 - loss: 0.9855
# Epoch 6/6 - loss: 0.9208
# Predicting with AGP...
# Adding features
# Training with 17187 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.2617
# Epoch 2/6 - loss: 1.9064
# Epoch 3/6 - loss: 1.6364
# Epoch 4/6 - loss: 1.4633
# Epoch 5/6 - loss: 1.3508
# Epoch 6/6 - loss: 1.2706
# Predicting with AGP...
# Exported combined results to /kaggle/working/sklearn_forecast_2024_cluster_specific_combined_case3_clusters.csv
# Skipping global-with-cluster-feature forecasts for case3_clusters (RUN_GLOBAL_WITH_CLUSTER_FEATURE=False)
# ## CLUSTERING FILE: /kaggle/input/datasets/michalbarnas/feature-based-clustering/case4_clusters.csv
# Skipping global per-cluster forecasts for case4_clusters (RUN_GLOBAL_TRAIN_CLUSTER=False)
# Skipping combined global per-cluster forecasts for case4_clusters (RUN_GLOBAL_TRAIN_CLUSTER_COMBINED=False)
# Adding features
# Training with 51898 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 1.0854
# Epoch 2/6 - loss: 0.5871
# Epoch 3/6 - loss: 0.2819
# Epoch 4/6 - loss: -0.0125
# Epoch 5/6 - loss: -0.3049
# Epoch 6/6 - loss: -0.5937
# Predicting with AGP...
# Adding features
# Training with 1073682 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 0.7633
# Epoch 2/6 - loss: 0.5055
# Epoch 3/6 - loss: 0.4915
# Epoch 4/6 - loss: 0.4863
# Epoch 5/6 - loss: 0.4835
# Epoch 6/6 - loss: 0.4817
# Predicting with AGP...
# Adding features
# Training with 1146137 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 0.6885
# Epoch 2/6 - loss: 0.4115
# Epoch 3/6 - loss: 0.3956
# Epoch 4/6 - loss: 0.3903
# Epoch 5/6 - loss: 0.3880
# Epoch 6/6 - loss: 0.3865
# Predicting with AGP...
# Adding features
# Training with 1341260 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 0.8190
# Epoch 2/6 - loss: 0.6327
# Epoch 3/6 - loss: 0.6184
# Epoch 4/6 - loss: 0.6132
# Epoch 5/6 - loss: 0.6104
# Epoch 6/6 - loss: 0.6086
# Predicting with AGP...
# Adding features
# Training with 2049297 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 0.5273
# Epoch 2/6 - loss: 0.3590
# Epoch 3/6 - loss: 0.3515
# Epoch 4/6 - loss: 0.3480
# Epoch 5/6 - loss: 0.3457
# Epoch 6/6 - loss: 0.3441
# Predicting with AGP...
# Adding features
# Training with 149291 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 1.4422
# Epoch 2/6 - loss: 0.8797
# Epoch 3/6 - loss: 0.6282
# Epoch 4/6 - loss: 0.5382
# Epoch 5/6 - loss: 0.4992
# Epoch 6/6 - loss: 0.4768
# Predicting with AGP...
# Adding features
# Training with 1011 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.4498
# Epoch 2/6 - loss: 2.4210
# Epoch 3/6 - loss: 2.3932
# Epoch 4/6 - loss: 2.3650
# Epoch 5/6 - loss: 2.3381
# Epoch 6/6 - loss: 2.3117
# Predicting with AGP...
# Adding features
# Training with 1348 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.4472
# Epoch 2/6 - loss: 2.4110
# Epoch 3/6 - loss: 2.3760
# Epoch 4/6 - loss: 2.3421
# Epoch 5/6 - loss: 2.3091
# Epoch 6/6 - loss: 2.2768
# Predicting with AGP...
# Adding features
# Training with 87957 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 1.7286
# Epoch 2/6 - loss: 1.1751
# Epoch 3/6 - loss: 0.9768
# Epoch 4/6 - loss: 0.8278
# Epoch 5/6 - loss: 0.7364
# Epoch 6/6 - loss: 0.6881
# Predicting with AGP...
# Adding features
# Training with 4718 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.4028
# Epoch 2/6 - loss: 2.2817
# Epoch 3/6 - loss: 2.1720
# Epoch 4/6 - loss: 2.0717
# Epoch 5/6 - loss: 1.9798
# Epoch 6/6 - loss: 1.8960
# Predicting with AGP...
# Adding features
# Training with 6740 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.3779
# Epoch 2/6 - loss: 2.2136
# Epoch 3/6 - loss: 2.0674
# Epoch 4/6 - loss: 1.9356
# Epoch 5/6 - loss: 1.8174
# Epoch 6/6 - loss: 1.7127
# Predicting with AGP...
# Exported combined results to /kaggle/working/sklearn_forecast_2024_cluster_specific_combined_case4_clusters.csv
# Skipping global-with-cluster-feature forecasts for case4_clusters (RUN_GLOBAL_WITH_CLUSTER_FEATURE=False)
# ## CLUSTERING FILE: /kaggle/input/datasets/michalbarnas/feature-based-clustering/case5_clusters.csv
# Skipping global per-cluster forecasts for case5_clusters (RUN_GLOBAL_TRAIN_CLUSTER=False)
# Skipping combined global per-cluster forecasts for case5_clusters (RUN_GLOBAL_TRAIN_CLUSTER_COMBINED=False)
# Adding features
# Training with 51898 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 1.0856
# Epoch 2/6 - loss: 0.5891
# Epoch 3/6 - loss: 0.2843
# Epoch 4/6 - loss: -0.0104
# Epoch 5/6 - loss: -0.3033
# Epoch 6/6 - loss: -0.5924
# Predicting with AGP...
# Adding features
# Training with 952699 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 0.6618
# Epoch 2/6 - loss: 0.3125
# Epoch 3/6 - loss: 0.2922
# Epoch 4/6 - loss: 0.2851
# Epoch 5/6 - loss: 0.2817
# Epoch 6/6 - loss: 0.2800
# Predicting with AGP...
# Adding features
# Training with 1803287 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 0.5058
# Epoch 2/6 - loss: 0.3062
# Epoch 3/6 - loss: 0.2969
# Epoch 4/6 - loss: 0.2923
# Epoch 5/6 - loss: 0.2895
# Epoch 6/6 - loss: 0.2875
# Predicting with AGP...
# Adding features
# Training with 2852705 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 0.7337
# Epoch 2/6 - loss: 0.6308
# Epoch 3/6 - loss: 0.6251
# Epoch 4/6 - loss: 0.6227
# Epoch 5/6 - loss: 0.6215
# Epoch 6/6 - loss: 0.6208
# Predicting with AGP...
# Adding features
# Training with 1685 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.4388
# Epoch 2/6 - loss: 2.3775
# Epoch 3/6 - loss: 2.3211
# Epoch 4/6 - loss: 2.2670
# Epoch 5/6 - loss: 2.2155
# Epoch 6/6 - loss: 2.1663
# Predicting with AGP...
# Adding features
# Training with 94360 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 1.6335
# Epoch 2/6 - loss: 1.1575
# Epoch 3/6 - loss: 0.9950
# Epoch 4/6 - loss: 0.8799
# Epoch 5/6 - loss: 0.8131
# Epoch 6/6 - loss: 0.7752
# Predicting with AGP...
# Adding features
# Training with 28308 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.0447
# Epoch 2/6 - loss: 1.4914
# Epoch 3/6 - loss: 1.2566
# Epoch 4/6 - loss: 1.1285
# Epoch 5/6 - loss: 1.0303
# Epoch 6/6 - loss: 0.9403
# Predicting with AGP...
# Adding features
# Training with 28982 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.0062
# Epoch 2/6 - loss: 1.5830
# Epoch 3/6 - loss: 1.4389
# Epoch 4/6 - loss: 1.3677
# Epoch 5/6 - loss: 1.3221
# Epoch 6/6 - loss: 1.2893
# Predicting with AGP...
# Adding features
# Training with 15502 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.2497
# Epoch 2/6 - loss: 1.9074
# Epoch 3/6 - loss: 1.6769
# Epoch 4/6 - loss: 1.5247
# Epoch 5/6 - loss: 1.4227
# Epoch 6/6 - loss: 1.3513
# Predicting with AGP...
# Adding features
# Training with 66726 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 1.9187
# Epoch 2/6 - loss: 1.3658
# Epoch 3/6 - loss: 1.1920
# Epoch 4/6 - loss: 1.0783
# Epoch 5/6 - loss: 0.9853
# Epoch 6/6 - loss: 0.9197
# Predicting with AGP...
# Adding features
# Training with 17187 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.2616
# Epoch 2/6 - loss: 1.9058
# Epoch 3/6 - loss: 1.6368
# Epoch 4/6 - loss: 1.4640
# Epoch 5/6 - loss: 1.3514
# Epoch 6/6 - loss: 1.2715
# Predicting with AGP...
# Exported combined results to /kaggle/working/sklearn_forecast_2024_cluster_specific_combined_case5_clusters.csv
# Skipping global-with-cluster-feature forecasts for case5_clusters (RUN_GLOBAL_WITH_CLUSTER_FEATURE=False)
# ## CLUSTERING FILE: /kaggle/input/datasets/michalbarnas/feature-based-clustering/case6_clusters.csv
# Skipping global per-cluster forecasts for case6_clusters (RUN_GLOBAL_TRAIN_CLUSTER=False)
# Skipping combined global per-cluster forecasts for case6_clusters (RUN_GLOBAL_TRAIN_CLUSTER_COMBINED=False)
# Adding features
# Training with 51898 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 1.0859
# Epoch 2/6 - loss: 0.5874
# Epoch 3/6 - loss: 0.2829
# Epoch 4/6 - loss: -0.0111
# Epoch 5/6 - loss: -0.3035
# Epoch 6/6 - loss: -0.5927
# Predicting with AGP...
# Adding features
# Training with 952699 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 0.6596
# Epoch 2/6 - loss: 0.3127
# Epoch 3/6 - loss: 0.2922
# Epoch 4/6 - loss: 0.2852
# Epoch 5/6 - loss: 0.2818
# Epoch 6/6 - loss: 0.2800
# Predicting with AGP...
# Adding features
# Training with 1803287 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 0.5064
# Epoch 2/6 - loss: 0.3060
# Epoch 3/6 - loss: 0.2966
# Epoch 4/6 - loss: 0.2923
# Epoch 5/6 - loss: 0.2893
# Epoch 6/6 - loss: 0.2871
# Predicting with AGP...
# Adding features
# Training with 2852705 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 0.7344
# Epoch 2/6 - loss: 0.6310
# Epoch 3/6 - loss: 0.6255
# Epoch 4/6 - loss: 0.6229
# Epoch 5/6 - loss: 0.6216
# Epoch 6/6 - loss: 0.6208
# Predicting with AGP...
# Adding features
# Training with 1685 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.4385
# Epoch 2/6 - loss: 2.3771
# Epoch 3/6 - loss: 2.3201
# Epoch 4/6 - loss: 2.2657
# Epoch 5/6 - loss: 2.2140
# Epoch 6/6 - loss: 2.1647
# Predicting with AGP...
# Adding features
# Training with 149291 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 1.4406
# Epoch 2/6 - loss: 0.8781
# Epoch 3/6 - loss: 0.6269
# Epoch 4/6 - loss: 0.5368
# Epoch 5/6 - loss: 0.4977
# Epoch 6/6 - loss: 0.4760
# Predicting with AGP...
# Adding features
# Training with 1011 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.4504
# Epoch 2/6 - loss: 2.4213
# Epoch 3/6 - loss: 2.3935
# Epoch 4/6 - loss: 2.3653
# Epoch 5/6 - loss: 2.3384
# Epoch 6/6 - loss: 2.3119
# Predicting with AGP...
# Adding features
# Training with 1348 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.4473
# Epoch 2/6 - loss: 2.4109
# Epoch 3/6 - loss: 2.3764
# Epoch 4/6 - loss: 2.3420
# Epoch 5/6 - loss: 2.3091
# Epoch 6/6 - loss: 2.2768
# Predicting with AGP...
# Adding features
# Training with 87957 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 1.7262
# Epoch 2/6 - loss: 1.1743
# Epoch 3/6 - loss: 0.9759
# Epoch 4/6 - loss: 0.8260
# Epoch 5/6 - loss: 0.7346
# Epoch 6/6 - loss: 0.6882
# Predicting with AGP...
# Adding features
# Training with 4718 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.4024
# Epoch 2/6 - loss: 2.2807
# Epoch 3/6 - loss: 2.1706
# Epoch 4/6 - loss: 2.0705
# Epoch 5/6 - loss: 1.9781
# Epoch 6/6 - loss: 1.8941
# Predicting with AGP...
# Adding features
# Training with 6740 samples
# Standardizing features and target
# Initializing 512 inducing points using k-means centers
# Fitting AGP model
# Epoch 1/6 - loss: 2.3780
# Epoch 2/6 - loss: 2.2134
# Epoch 3/6 - loss: 2.0664
# Epoch 4/6 - loss: 1.9344
# Epoch 5/6 - loss: 1.8166
# Epoch 6/6 - loss: 1.7115
# Predicting with AGP...
# Exported combined results to /kaggle/working/sklearn_forecast_2024_cluster_specific_combined_case6_clusters.csv
# Skipping global-with-cluster-feature forecasts for case6_clusters (RUN_GLOBAL_WITH_CLUSTER_FEATURE=False)
# Evaluation Summary
# clustering_used                             label  n_eval_points       mae      rmse  cvrmse_pct  nrmse_range
#  case1_clusters cluster_specific_train_cluster_-1          56364  0.080844  1.478830 1838.496909     0.019134
#  case1_clusters  cluster_specific_train_cluster_0        4626606  2.429995  4.943492   64.024395     0.011777
#  case1_clusters  cluster_specific_train_cluster_1         765306  5.997574 13.027646  127.130792     0.028849
#  case1_clusters  cluster_specific_train_cluster_2         701256  8.838909 14.953623   77.225389     0.032664
#  case1_clusters  cluster_specific_train_cluster_3         102480  2.920253  9.260360  389.554966     0.015495
#  case1_clusters  cluster_specific_train_cluster_4          30744 12.841482 24.051894  165.269846     0.070356
#  case1_clusters  cluster_specific_train_cluster_5          31476  2.081498 14.203607  828.665059     0.030260
#  case1_clusters  cluster_specific_train_cluster_6          16836  5.005659 11.210065  221.232050     0.058205
#  case1_clusters  cluster_specific_train_cluster_7          72468  1.662119  2.953227  116.424563     0.034897
#  case1_clusters  cluster_specific_train_cluster_8          18666  9.557605 14.631372  132.520604     0.146982
#  case1_clusters   cluster_specific_train_combined        6422202  3.609076  8.273000   91.025447     0.013843
#  case2_clusters cluster_specific_train_cluster_-1          56364  0.080690  1.478833 1838.501426     0.019134
#  case2_clusters  cluster_specific_train_cluster_0         713700  9.068215 15.720487   81.872108     0.034339
#  case2_clusters  cluster_specific_train_cluster_1        1178154  5.144904 11.835577  123.199530     0.026209
#  case2_clusters  cluster_specific_train_cluster_2        4201314  2.310420  4.648814   60.802511     0.011075
#  case2_clusters  cluster_specific_train_cluster_3         162138  5.063707 13.915881  304.012174     0.023285
#  case2_clusters  cluster_specific_train_cluster_4           1098  0.582893  0.717214  108.301447     0.211380
#  case2_clusters  cluster_specific_train_cluster_5           1464  0.912037  1.150932   80.842435     0.162378
#  case2_clusters  cluster_specific_train_cluster_6          95526  3.664609  7.483380  173.426199     0.038855
#  case2_clusters  cluster_specific_train_cluster_7           5124  3.513723  6.547747  126.960957     0.135197
#  case2_clusters  cluster_specific_train_cluster_8           7320  3.908601  7.026474  140.539189     0.158999
#  case2_clusters   cluster_specific_train_combined        6422202  3.653653  8.551716   94.092080     0.014309
#  case3_clusters cluster_specific_train_cluster_-1          56364  0.082019  1.478761 1838.411335     0.019133
#  case3_clusters  cluster_specific_train_cluster_0        1166076  2.509232  5.946242   86.947622     0.013370
#  case3_clusters  cluster_specific_train_cluster_1        1244766  4.453676 10.495741  100.344207     0.023242
#  case3_clusters  cluster_specific_train_cluster_2        1456680  2.428367  5.927165   79.557803     0.014116
#  case3_clusters  cluster_specific_train_cluster_3        2225646  4.434691  9.338310   82.157507     0.020398
#  case3_clusters  cluster_specific_train_cluster_4         102480  2.909478  9.256585  389.396135     0.015489
#  case3_clusters  cluster_specific_train_cluster_5          30744 13.024360 24.163871  166.039284     0.070683
#  case3_clusters  cluster_specific_train_cluster_6          31476  2.072373 14.205642  828.783744     0.030264
#  case3_clusters  cluster_specific_train_cluster_7          16836  4.981275 11.227464  221.575409     0.058295
#  case3_clusters  cluster_specific_train_cluster_8          72468  1.563800  2.845671  112.184403     0.033626
#  case3_clusters  cluster_specific_train_cluster_9          18666  9.567567 14.635447  132.557513     0.147023
#  case3_clusters   cluster_specific_train_combined        6422202  3.584652  8.495647   93.475170     0.014216
#  case4_clusters cluster_specific_train_cluster_-1          56364  0.080682  1.478838 1838.506873     0.019134
#  case4_clusters  cluster_specific_train_cluster_0        1166076  2.498664  5.797837   84.777599     0.013036
#  case4_clusters  cluster_specific_train_cluster_1        1244766  4.221210  9.943448   95.064026     0.022019
#  case4_clusters  cluster_specific_train_cluster_2        1456680  2.461693  5.975423   80.205549     0.014231
#  case4_clusters  cluster_specific_train_cluster_3        2225646  4.460352  9.473685   83.348522     0.020694
#  case4_clusters  cluster_specific_train_cluster_4         162138  5.015036 13.822740  301.977371     0.023129
#  case4_clusters  cluster_specific_train_cluster_5           1098  0.582770  0.716975  108.265409     0.211310
#  case4_clusters  cluster_specific_train_cluster_6           1464  0.910864  1.149583   80.747731     0.162187
#  case4_clusters  cluster_specific_train_cluster_7          95526  3.795355  8.095422  187.610180     0.042033
#  case4_clusters  cluster_specific_train_cluster_8           5124  3.520893  6.571396  127.419524     0.135686
#  case4_clusters  cluster_specific_train_cluster_9           7320  3.907411  7.024404  140.497777     0.158952
#  case4_clusters   cluster_specific_train_combined        6422202  3.567306  8.389174   92.303686     0.014037
#  case5_clusters cluster_specific_train_cluster_-1          56364  0.081882  1.478769 1838.420908     0.019133
#  case5_clusters  cluster_specific_train_cluster_0        1034682  3.759558  8.953676   90.741913     0.020132
#  case5_clusters  cluster_specific_train_cluster_1        1958466  5.028675 10.141733   79.289864     0.022153
#  case5_clusters  cluster_specific_train_cluster_2        3098190  2.349173  5.854025   82.916630     0.012963
#  case5_clusters  cluster_specific_train_cluster_3           1830  5.356710  8.886220  143.684363     0.189310
#  case5_clusters  cluster_specific_train_cluster_4         102480  2.889475  9.225423  388.085257     0.015437
#  case5_clusters  cluster_specific_train_cluster_5          30744 13.179247 24.278463  166.826691     0.071019
#  case5_clusters  cluster_specific_train_cluster_6          31476  2.081769 14.203570  828.662866     0.030259
#  case5_clusters  cluster_specific_train_cluster_7          16836  4.982896 11.217909  221.386856     0.058246
#  case5_clusters  cluster_specific_train_cluster_8          72468  1.616063  2.876280  113.391092     0.033988
#  case5_clusters  cluster_specific_train_cluster_9          18666  9.540168 14.597270  132.211733     0.146640
#  case5_clusters   cluster_specific_train_combined        6422202  3.453168  8.189437   90.106035     0.013703
#  case6_clusters cluster_specific_train_cluster_-1          56364  0.081223  1.478804 1838.465398     0.019134
#  case6_clusters  cluster_specific_train_cluster_0        1034682  3.880938  9.298253   94.234065     0.020906
#  case6_clusters  cluster_specific_train_cluster_1        1958466  5.377428 10.803616   84.464589     0.023599
#  case6_clusters  cluster_specific_train_cluster_2        3098190  2.361080  5.861271   83.019268     0.012980
#  case6_clusters  cluster_specific_train_cluster_3           1830  5.358258  8.875386  143.509190     0.189079
#  case6_clusters  cluster_specific_train_cluster_4         162138  4.925844 13.797373  301.423189     0.023087
#  case6_clusters  cluster_specific_train_cluster_5           1098  0.582643  0.716744  108.230463     0.211242
#  case6_clusters  cluster_specific_train_cluster_6           1464  0.911739  1.150696   80.825864     0.162344
#  case6_clusters  cluster_specific_train_cluster_7          95526  4.108756  8.621459  199.801005     0.044764
#  case6_clusters  cluster_specific_train_cluster_8           5124  3.519481  6.565204  127.299445     0.135558
#  case6_clusters  cluster_specific_train_cluster_9           7320  3.909871  7.039105  140.791824     0.159285
#  case6_clusters   cluster_specific_train_combined        6422202  3.599434  8.493557   93.452181     0.014212
#
# Averages
# mae              3.892824
# rmse             8.530341
# cvrmse_pct     314.393074
# nrmse_range      0.060616
